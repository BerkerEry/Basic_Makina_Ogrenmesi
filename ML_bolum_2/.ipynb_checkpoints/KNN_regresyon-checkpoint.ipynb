# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, scale
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### KNN

# %%
df = pd.read_csv("Hitters.csv")
df = df.dropna()

#one-hot encoding
dms = pd.get_dummies(df[["League", "Division", "NewLeague"]])

y = df["Salary"]
X_ = df.drop(["Salary", "League", "Division", "NewLeague"], axis = 1).astype("float64")
X = pd.concat([X_, dms[["League_N", "Division_W", "NewLeague_N"]]], axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size = 0.25,
                                                    random_state = 42)

# %%
X_train.head()
# Out:
#      AtBat   Hits  HmRun  Runs  ...  Errors  League_N  Division_W  NewLeague_N
# 183  328.0   91.0   12.0  51.0  ...     8.0      True       False         True
# 229  514.0  144.0    0.0  67.0  ...    15.0      True       False         True
# 286  593.0  152.0   23.0  69.0  ...     6.0     False        True        False
# 102  233.0   49.0    2.0  41.0  ...    10.0     False       False        False
# 153  341.0   95.0    6.0  48.0  ...     5.0      True        True         True
#
# [5 rows x 19 columns]

# %% [markdown]
# #### Model & Tahmin

# %%
knn_model = KNeighborsRegressor().fit(X_train, y_train)

# %%
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.n_neighbors
# Out:
# 5

# %%
knn_model.metric
# Out:
# 'minkowski'

# %%
knn_model.predict(X_test)[0:5]
# Out:
# array([ 510.3334,  808.3334,  772.5   ,  125.5   , 1005.    ])

# %%
y_pred = knn_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 426.6570764525201

# %% [markdown]
# #### Model Tuning

# %%
RMSE = []

for k in range(10):
    k = k+1
    knn_model = KNeighborsRegressor(n_neighbors = k).fit(X_train, y_train)
    y_pred = knn_model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    RMSE.append(rmse)
    print("k=", k, " için RMSE değeri: ", rmse)
# Out:
# k= 1  için RMSE değeri:  455.03925390751965
# k= 2  için RMSE değeri:  415.99629571490965
# k= 3  için RMSE değeri:  420.6765370082348
# k= 4  için RMSE değeri:  428.8564674588792
# k= 5  için RMSE değeri:  426.6570764525201
# k= 6  için RMSE değeri:  423.5071669008732
# k= 7  için RMSE değeri:  414.9361222421057
# k= 8  için RMSE değeri:  413.7094731463598
# k= 9  için RMSE değeri:  417.84419990871265
# k= 10  için RMSE değeri:  421.6252180741266

# %%
# GridSearchCV

# %%
knn_params = {"n_neighbors": np.arange(1,30,1)}

# %%
knn = KNeighborsRegressor()

# %%
knn_cv_model = GridSearchCV(knn, knn_params, cv = 10).fit(X_train, y_train)

# %%
knn_cv_model.best_params_
# Out:
# {'n_neighbors': 8}

# %%
# final model
knn_tuned = knn = KNeighborsRegressor(n_neighbors = knn_cv_model.best_params_["n_neighbors"]).fit(X_train, y_train)

# %%
y_pred = knn_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 413.7094731463598
